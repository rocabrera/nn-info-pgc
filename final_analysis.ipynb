# %%
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("resultados_test.csv")

df.query("epoch==0")
# Out:
#       epoch  rand_init  layer           T          Y
# 0         0          0      1  303.642202  36.664939
# 1         0          0      2  295.105557  28.128295
# 2         0          0      3  267.929898   0.952635
# 3         0          0      4  267.929898   0.952635
# 400       0          1      1  286.234467  19.257205
# 401       0          1      2  296.395547  29.418284
# 402       0          1      3  276.586237   9.608975
# 403       0          1      4  268.282871   1.305608
# 800       0          2      1  304.452353  37.475091
# 801       0          2      2  279.574194  12.596931
# 802       0          2      3  277.040003  10.062741
# 803       0          2      4  268.004343   1.027081
# 1200      0          3      1  304.721502  37.744239
# 1201      0          3      2  313.691322  46.714059
# 1202      0          3      3  286.234467  19.257205
# 1203      0          3      4  277.082183  10.104920
# 1600      0          4      1  302.830021  35.852758
# 1601      0          4      2  295.386752  28.409490
# 1602      0          4      3  277.082183  10.104920
# 1603      0          4      4  277.082183  10.104920
# 2000      0          5      1  331.995892  65.018629
# 2001      0          5      2  267.929898   0.952635
# 2002      0          5      3  277.082183  10.104920
# 2003      0          5      4  267.929898   0.952635
# 2400      0          6      1  313.421410  46.444147
# 2401      0          6      2  295.386752  28.409490
# 2402      0          6      3  267.929898   0.952635
# 2403      0          6      4  258.777613   0.000000
# 2800      0          7      1  305.147804  38.170541
# 2801      0          7      2  295.386752  28.409490
# 2802      0          7      3  286.207209  19.229947
# 2803      0          7      4  258.777613   0.000000
# 3200      0          8      1  293.213341  26.236078
# 3201      0          8      2  294.001484  27.024221
# 3202      0          8      3  267.967129   0.989867
# 3203      0          8      4  267.967129   0.989867
# 3600      0          9      1  316.585985  49.608722
# 3601      0          9      2  286.234467  19.257205
# 3602      0          9      3  277.082183  10.104920
# 3603      0          9      4  276.812270   9.835008

# %%
scaler = StandardScaler()

scaler.fit_transform()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_32248/3678610069.py in <module>
# ----> 1 scaler = StandardScaler()
#       2
#       3 scaler.fit_transform()
#
# NameError: name 'StandardScaler' is not defined

# %%
sns.scatterplot(data=df.query("epoch==99"), x="T", y="Y", hue="layer")
# Out:
# <AxesSubplot:xlabel='T', ylabel='Y'>
