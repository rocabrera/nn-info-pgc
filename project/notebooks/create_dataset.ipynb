# %%
from sklearn.datasets import make_moons, make_circles
from matplotlib import pyplot
from pandas import DataFrame
# generate 2d classification dataset
X, y = make_circles(n_samples=10000, noise=0.1, factor=0.65)
# scatter plot, dots colored by class value
df = DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
colors = {0:'red', 1:'blue'}
fig, ax = pyplot.subplots()
grouped = df.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
pyplot.show()

# %%
df.to_csv("data/sample_dataset_circles.csv", index=False)

# %%
from sklearn.datasets import load_breast_cancer

data = load_breast_cancer(as_frame=True)

# %%
data["target"]
CancerDataset
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 564    0
# 565    0
# 566    0
# 567    0
# 568    1
# Name: target, Length: 569, dtype: int64

# %%
from glob import glob

filenames = sorted([file for file in glob("gif_test2/*")], key=lambda x:int(x.split(".png")[0][17:]))

import imageio
with imageio.get_writer('fst_trial.gif', mode='I',duration=0.02) as writer:
    for filename in filenames:
        image = imageio.imread(filename)
        writer.append_data(image)
